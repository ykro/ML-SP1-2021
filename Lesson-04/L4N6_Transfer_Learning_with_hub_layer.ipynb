# %% [markdown]
# <a href="https://colab.research.google.com/github/ykro/ML-SP1-2021/blob/main/Lesson-04/L4N6_Transfer_Learning_with_hub_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_hub as hub

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from google.colab import files

import os
import numpy as np
import PIL.Image as Image
import matplotlib.pyplot as plt

plt.rc_context({'xtick.color':'w', 'ytick.color':'w', 'text.color':'w', 'axes.labelcolor':'w'})

seed=1234
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
steps = 20
epochs = 20
batch_size = 64
image_size = (150, 150)
class_names = np.array(['cat','dog'])
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'

# %%
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %%
#!ls ~/.keras/datasets/cats_and_dogs_filtered/train/cats
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  
train_dogs_dir = os.path.join(train_dir, 'dogs')  
validation_cats_dir = os.path.join(validation_dir, 'cats') 
validation_dogs_dir = os.path.join(validation_dir, 'dogs') 

num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))
num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %%
def build_model(layers, opt=Adam()):
  model = Sequential(layers)

  model.compile(optimizer=opt,
                loss='binary_crossentropy',
                metrics=['accuracy'])
  
  model.summary()

  return model

def plot_images(imgs,labels=np.array([])):
  plt.figure(figsize=(15,15))
  plt.subplots_adjust(hspace=0.5)

  for i in range(10):
    plt.axis("off")
    plt.subplot(4,5,i+1)
    plt.imshow(imgs[i])
    if labels.size:
      plt.title(class_names[int(labels[i])])

def plot_model(history, prev_history=None):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss'] 

  if prev_history is not None:
    acc = prev_history.history['accuracy'] + acc
    val_acc = prev_history.history['val_accuracy'] + val_acc

    loss = prev_history.history['loss'] + loss
    val_loss = prev_history.history['val_loss'] + val_loss

    initial_epochs = len(prev_history.history['accuracy'])

  plt.figure(figsize=(10, 10))

  plt.subplot(2, 1, 1)
  plt.plot(acc, label='Training Accuracy')
  plt.plot(val_acc, label='Validation Accuracy')
  
  if prev_history is not None:
    plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')

  plt.legend(loc='lower right')
  plt.setp(plt.legend().get_texts(), color='black')
  plt.ylabel('Accuracy')
  plt.title('Training and Validation Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss')

  if prev_history is not None:
    plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
      
  plt.legend(loc='upper right')
  plt.setp(plt.legend().get_texts(), color='black')
  plt.ylabel('Loss')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epoch')
  plt.show()

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(
    batch_size=batch_size,
    directory=train_dir,
    shuffle=True,
    target_size=image_size,
    class_mode='binary'
)

val_data_gen = train_image_generator.flow_from_directory(
    batch_size=batch_size,
    directory=validation_dir,
    shuffle=True,
    target_size=image_size,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
sample_train_images, sample_train_labels = next(train_data_gen)
sample_train_images.shape, sample_train_labels.shape
# Out:
# ((64, 150, 150, 3), (64,))

# %%
plot_images(sample_train_images, sample_train_labels)

# %%
m0 = build_model([
  Flatten(input_shape=image_size+(3,)),
  Dense(1024, activation='relu'),
  Dense(1, activation='sigmoid')
])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 67500)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              69121024
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 69,122,049
# Trainable params: 69,122,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
h0 = m0.fit(
  train_data_gen,
  epochs=epochs,
  steps_per_epoch=steps,
  validation_data=val_data_gen,
  validation_steps=steps // 2
)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 7s 278ms/step - loss: 50.6798 - accuracy: 0.5039 - val_loss: 26.1288 - val_accuracy: 0.5000
# Epoch 2/20
# 20/20 [==============================] - 5s 268ms/step - loss: 11.4828 - accuracy: 0.5108 - val_loss: 2.5910 - val_accuracy: 0.5406
# Epoch 3/20
# 20/20 [==============================] - 5s 261ms/step - loss: 2.3608 - accuracy: 0.5507 - val_loss: 6.4439 - val_accuracy: 0.4922
# Epoch 4/20
# 20/20 [==============================] - 5s 261ms/step - loss: 3.7660 - accuracy: 0.5420 - val_loss: 5.5447 - val_accuracy: 0.5125
# Epoch 5/20
# 20/20 [==============================] - 5s 269ms/step - loss: 3.8390 - accuracy: 0.5444 - val_loss: 1.1576 - val_accuracy: 0.5766
# Epoch 6/20
# 20/20 [==============================] - 5s 257ms/step - loss: 1.3742 - accuracy: 0.6041 - val_loss: 5.9007 - val_accuracy: 0.4938
# Epoch 7/20
# 20/20 [==============================] - 5s 264ms/step - loss: 4.0588 - accuracy: 0.5278 - val_loss: 1.1575 - val_accuracy: 0.5719
# Epoch 8/20
# 20/20 [==============================] - 5s 256ms/step - loss: 1.8577 - accuracy: 0.5833 - val_loss: 2.4382 - val_accuracy: 0.5219
# Epoch 9/20
# 20/20 [==============================] - 5s 258ms/step - loss: 1.8185 - accuracy: 0.5921 - val_loss: 2.6582 - val_accuracy: 0.5109
# Epoch 10/20
# 20/20 [==============================] - 5s 256ms/step - loss: 1.3326 - accuracy: 0.5680 - val_loss: 1.5313 - val_accuracy: 0.5359
# Epoch 11/20
# 20/20 [==============================] - 5s 264ms/step - loss: 2.1136 - accuracy: 0.5303 - val_loss: 2.2287 - val_accuracy: 0.5219
# Epoch 12/20
# 20/20 [==============================] - 5s 273ms/step - loss: 1.5191 - accuracy: 0.5976 - val_loss: 1.7131 - val_accuracy: 0.5203
# Epoch 13/20
# 20/20 [==============================] - 5s 260ms/step - loss: 1.6375 - accuracy: 0.5690 - val_loss: 1.8270 - val_accuracy: 0.5328
# Epoch 14/20
# 20/20 [==============================] - 5s 256ms/step - loss: 0.9040 - accuracy: 0.6542 - val_loss: 1.0620 - val_accuracy: 0.5453
# Epoch 15/20
# 20/20 [==============================] - 5s 264ms/step - loss: 0.7218 - accuracy: 0.6583 - val_loss: 0.8706 - val_accuracy: 0.5625
# Epoch 16/20
# 20/20 [==============================] - 5s 255ms/step - loss: 0.7394 - accuracy: 0.6775 - val_loss: 1.2424 - val_accuracy: 0.5391
# Epoch 17/20
# 20/20 [==============================] - 5s 262ms/step - loss: 0.7660 - accuracy: 0.6610 - val_loss: 1.0185 - val_accuracy: 0.5359
# Epoch 18/20
# 20/20 [==============================] - 5s 263ms/step - loss: 0.5493 - accuracy: 0.7167 - val_loss: 2.2816 - val_accuracy: 0.4875
# Epoch 19/20
# 20/20 [==============================] - 5s 258ms/step - loss: 1.0439 - accuracy: 0.6113 - val_loss: 0.8483 - val_accuracy: 0.5828
# Epoch 20/20
# 20/20 [==============================] - 5s 260ms/step - loss: 0.7540 - accuracy: 0.6744 - val_loss: 1.3996 - val_accuracy: 0.5172

# %%
plot_model(h0)

# %%
augmented_image_gen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=15
)

augmented_train_data_gen = augmented_image_gen.flow_from_directory(
    batch_size=batch_size,
    directory=train_dir,
    shuffle=True,
    target_size=image_size,
    class_mode='binary'
)

augmented_val_data_gen = augmented_image_gen.flow_from_directory(
    batch_size=batch_size,
    directory=validation_dir,
    target_size=image_size,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
plot_images([augmented_train_data_gen[0][0][0] for i in range(10)])

# %%
m1 = build_model([
  Flatten(input_shape=image_size+(3,)),
  Dense(1024, activation='relu'),
  Dropout(0.2),
  Dense(1, activation='sigmoid')
])

h1 = m1.fit(
  augmented_train_data_gen,
  epochs=epochs,
  steps_per_epoch=steps,
  validation_data=val_data_gen,
  validation_steps=steps // 2
)

plot_model(h1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 67500)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              69121024
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 69,122,049
# Trainable params: 69,122,049
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 20/20 [==============================] - 11s 528ms/step - loss: 105.1200 - accuracy: 0.4894 - val_loss: 3.5613 - val_accuracy: 0.5578
# Epoch 2/20
# 20/20 [==============================] - 10s 501ms/step - loss: 8.4593 - accuracy: 0.5209 - val_loss: 3.7010 - val_accuracy: 0.5234
# Epoch 3/20
# 20/20 [==============================] - 10s 521ms/step - loss: 2.7527 - accuracy: 0.5620 - val_loss: 1.4266 - val_accuracy: 0.4922
# Epoch 4/20
# 20/20 [==============================] - 10s 505ms/step - loss: 0.8891 - accuracy: 0.5428 - val_loss: 0.7080 - val_accuracy: 0.5422
# Epoch 5/20
# 20/20 [==============================] - 10s 510ms/step - loss: 0.6885 - accuracy: 0.5576 - val_loss: 0.6777 - val_accuracy: 0.5562
# Epoch 6/20
# 20/20 [==============================] - 10s 503ms/step - loss: 0.6840 - accuracy: 0.5596 - val_loss: 0.6784 - val_accuracy: 0.5609
# Epoch 7/20
# 20/20 [==============================] - 10s 516ms/step - loss: 0.6698 - accuracy: 0.5816 - val_loss: 0.6683 - val_accuracy: 0.5766
# Epoch 8/20
# 20/20 [==============================] - 10s 519ms/step - loss: 0.6805 - accuracy: 0.5818 - val_loss: 0.6765 - val_accuracy: 0.5406
# Epoch 9/20
# 20/20 [==============================] - 10s 504ms/step - loss: 0.6752 - accuracy: 0.5880 - val_loss: 0.6809 - val_accuracy: 0.5562
# Epoch 10/20
# 20/20 [==============================] - 10s 525ms/step - loss: 0.7259 - accuracy: 0.5437 - val_loss: 0.7013 - val_accuracy: 0.5000
# Epoch 11/20
# 20/20 [==============================] - 10s 502ms/step - loss: 0.6736 - accuracy: 0.5814 - val_loss: 0.6845 - val_accuracy: 0.5562
# Epoch 12/20
# 20/20 [==============================] - 10s 501ms/step - loss: 0.6795 - accuracy: 0.5570 - val_loss: 0.6761 - val_accuracy: 0.5719
# Epoch 13/20
# 20/20 [==============================] - 10s 508ms/step - loss: 0.6724 - accuracy: 0.6099 - val_loss: 0.6673 - val_accuracy: 0.5813
# Epoch 14/20
# 20/20 [==============================] - 10s 516ms/step - loss: 0.6827 - accuracy: 0.5555 - val_loss: 0.6700 - val_accuracy: 0.5672
# Epoch 15/20
# 20/20 [==============================] - 10s 510ms/step - loss: 0.6760 - accuracy: 0.5668 - val_loss: 0.6664 - val_accuracy: 0.5938
# Epoch 16/20
# 20/20 [==============================] - 10s 494ms/step - loss: 0.6595 - accuracy: 0.6258 - val_loss: 0.6644 - val_accuracy: 0.5906
# Epoch 17/20
# 20/20 [==============================] - 10s 513ms/step - loss: 0.6824 - accuracy: 0.5504 - val_loss: 0.6665 - val_accuracy: 0.6031
# Epoch 18/20
# 20/20 [==============================] - 10s 511ms/step - loss: 0.6602 - accuracy: 0.5914 - val_loss: 0.6641 - val_accuracy: 0.5906
# Epoch 19/20
# 20/20 [==============================] - 10s 515ms/step - loss: 0.6629 - accuracy: 0.5870 - val_loss: 0.6582 - val_accuracy: 0.6000
# Epoch 20/20
# 20/20 [==============================] - 10s 502ms/step - loss: 0.6691 - accuracy: 0.5792 - val_loss: 0.6770 - val_accuracy: 0.5828

# %%
feature_extractor_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"

feature_extractor_layer = hub.KerasLayer(feature_extractor_url,
                                         input_shape=image_size+(3,))

feature_extractor_layer.trainable = False

# %%
m2 = build_model([
  feature_extractor_layer,
  Dropout(0.2),
  Dense(1, activation='sigmoid')                 
])

h2 = m2.fit(
  augmented_train_data_gen,
  epochs=epochs,
  steps_per_epoch=steps,
  validation_data=val_data_gen,
  validation_steps=steps // 2
)

plot_model(h2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 2048)              23564800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/20
# 20/20 [==============================] - 20s 559ms/step - loss: 0.5040 - accuracy: 0.7952 - val_loss: 0.1517 - val_accuracy: 0.9484
# Epoch 2/20
# 20/20 [==============================] - 11s 551ms/step - loss: 0.1540 - accuracy: 0.9561 - val_loss: 0.1181 - val_accuracy: 0.9625
# Epoch 3/20
# 20/20 [==============================] - 11s 550ms/step - loss: 0.0901 - accuracy: 0.9655 - val_loss: 0.0952 - val_accuracy: 0.9688
# Epoch 4/20
# 20/20 [==============================] - 11s 548ms/step - loss: 0.1173 - accuracy: 0.9587 - val_loss: 0.0969 - val_accuracy: 0.9672
# Epoch 5/20
# 20/20 [==============================] - 11s 542ms/step - loss: 0.1105 - accuracy: 0.9648 - val_loss: 0.0950 - val_accuracy: 0.9625
# Epoch 6/20
# 20/20 [==============================] - 11s 561ms/step - loss: 0.0792 - accuracy: 0.9671 - val_loss: 0.1231 - val_accuracy: 0.9547
# Epoch 7/20
# 20/20 [==============================] - 11s 536ms/step - loss: 0.0708 - accuracy: 0.9694 - val_loss: 0.0909 - val_accuracy: 0.9688
# Epoch 8/20
# 20/20 [==============================] - 11s 553ms/step - loss: 0.0591 - accuracy: 0.9804 - val_loss: 0.0846 - val_accuracy: 0.9656
# Epoch 9/20
# 20/20 [==============================] - 11s 563ms/step - loss: 0.0702 - accuracy: 0.9671 - val_loss: 0.1322 - val_accuracy: 0.9547
# Epoch 10/20
# 20/20 [==============================] - 11s 530ms/step - loss: 0.0564 - accuracy: 0.9816 - val_loss: 0.0867 - val_accuracy: 0.9672
# Epoch 11/20
# 20/20 [==============================] - 11s 555ms/step - loss: 0.0708 - accuracy: 0.9719 - val_loss: 0.1186 - val_accuracy: 0.9563
# Epoch 12/20
# 20/20 [==============================] - 11s 533ms/step - loss: 0.0938 - accuracy: 0.9712 - val_loss: 0.0975 - val_accuracy: 0.9656
# Epoch 13/20
# 20/20 [==============================] - 11s 528ms/step - loss: 0.0927 - accuracy: 0.9610 - val_loss: 0.0986 - val_accuracy: 0.9703
# Epoch 14/20
# 20/20 [==============================] - 11s 533ms/step - loss: 0.0452 - accuracy: 0.9832 - val_loss: 0.0981 - val_accuracy: 0.9719
# Epoch 15/20
# 20/20 [==============================] - 11s 553ms/step - loss: 0.0611 - accuracy: 0.9748 - val_loss: 0.0694 - val_accuracy: 0.9641
# Epoch 16/20
# 20/20 [==============================] - 11s 538ms/step - loss: 0.0726 - accuracy: 0.9716 - val_loss: 0.0907 - val_accuracy: 0.9672
# Epoch 17/20
# 20/20 [==============================] - 11s 536ms/step - loss: 0.0679 - accuracy: 0.9689 - val_loss: 0.0745 - val_accuracy: 0.9734
# Epoch 18/20
# 20/20 [==============================] - 11s 534ms/step - loss: 0.0915 - accuracy: 0.9674 - val_loss: 0.0950 - val_accuracy: 0.9672
# Epoch 19/20
# 20/20 [==============================] - 11s 529ms/step - loss: 0.0346 - accuracy: 0.9859 - val_loss: 0.0975 - val_accuracy: 0.9703
# Epoch 20/20
# 20/20 [==============================] - 11s 548ms/step - loss: 0.0419 - accuracy: 0.9862 - val_loss: 0.1004 - val_accuracy: 0.9656
