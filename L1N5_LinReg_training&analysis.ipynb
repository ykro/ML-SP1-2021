# %% [markdown]
# <a href="https://colab.research.google.com/github/ykro/ML-SP1-2021/blob/main/L1N5_LinReg_training%26analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

seed=1234
np.random.seed(seed)
tf.random.set_seed(seed)

#dark theme
plt.rc_context({'xtick.color':'w', 'ytick.color':'w', 'text.color':'w', 'axes.labelcolor':'w'})

# %%
X = np.array([5,6,7,8,9,10,11,12]) #prices
Y = np.array([8.5, 8, 7.5, 7.0, 6.5, 6.0, 5.5, 5.0]) #units sold

X.shape, Y.shape
# Out:
# ((8,), (8,))

# %%
plt.scatter(X,Y)
plt.show()

# %%
model = Sequential([
                  Dense(units=1, input_shape=[1])
])

model.compile(
    optimizer='sgd',
    loss='mse'
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=500
history = model.fit(X, Y, epochs=epochs)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0121
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0067
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0013
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9960
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9906
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9853
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9800
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9747
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9694
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9641
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9589
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9536
# ...

# %%
plt.plot(range(epochs), history.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
zoom = 10
plt.plot(range(zoom), history.history['loss'][epochs-zoom:])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
prediction = model.predict([20])
print(prediction.squeeze())
# Out:
# 4.3344584
